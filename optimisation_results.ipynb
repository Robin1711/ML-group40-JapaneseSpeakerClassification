# %%
import skopt
import pickle
from skopt import plots
from glob import glob

folders=["RF"]#"BC", "DTC", "ESN", "KNN", "RF", 
for folder in folders:
    result_files = glob("opt/"+folder+"/*")
    res = []
    for result_file in result_files:
        print(result_file)
        results = skopt.load(result_file)        
        res.append((result_file, results))
    plots.plot_convergence(*res)
# Out:
# opt/RF\['pad', 'BACK', 15] ['truncate', 'BACK', 15] ['pca', 3] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'BACK', 15] ['truncate', 'BACK', 15] ['pca', 6] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'BACK', 15] ['truncate', 'BACK', 15] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'BACK', 20] ['truncate', 'BACK', 20] ['pca', 3] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'BACK', 20] ['truncate', 'BACK', 20] ['pca', 6] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'BACK', 20] ['truncate', 'BACK', 20] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'BACK', 25] ['truncate', 'BACK', 25] ['pca', 3] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'BACK', 25] ['truncate', 'BACK', 25] ['pca', 6] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'BACK', 25] ['truncate', 'BACK', 25] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'FRONT', 15] ['truncate', 'FRONT', 15] ['pca', 3] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'FRONT', 15] ['truncate', 'FRONT', 15] ['pca', 6] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'FRONT', 15] ['truncate', 'FRONT', 15] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'FRONT', 20] ['truncate', 'FRONT', 20] ['pca', 3] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'FRONT', 20] ['truncate', 'FRONT', 20] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'FRONT', 25] ['truncate', 'FRONT', 25] ['pca', 3] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['pad', 'FRONT', 25] ['truncate', 'FRONT', 25] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# opt/RF\['transpose'] ['auto_reg_coeff'] ['flatten'] ['onehot-to-labels'].pkl
