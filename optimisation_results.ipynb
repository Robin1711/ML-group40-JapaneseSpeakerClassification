# %%
import skopt
import pickle
from skopt import plots
from glob import glob

folders=["RF"]#"BC", "DTC", "ESN", "KNN", "RF", 
for folder in folders:
    result_files = glob("opt/"+folder+"/*")
    res = []
    for result_file in result_files:
        print(result_file)
        results = skopt.load(result_file)
        print('Best Validation Accuracy: {}'.format(-1.0 * results.fun))
        print('Best Params: {}'.format(results.x))     
        res.append((result_file, results))
    plots.plot_convergence(*res)
# Out:
# opt/RF\['pad', 'BACK', 15] ['truncate', 'BACK', 15] ['pca', 3] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.8888888888888887
# Best Params: [118, 'entropy']
# opt/RF\['pad', 'BACK', 15] ['truncate', 'BACK', 15] ['pca', 6] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9296296296296296
# Best Params: [147, 'entropy']
# opt/RF\['pad', 'BACK', 15] ['truncate', 'BACK', 15] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9555555555555555
# Best Params: [126, 'gini']
# opt/RF\['pad', 'BACK', 15] ['truncate', 'BACK', 15] ['transpose'] ['pca', 12] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9148148148148149
# Best Params: [160, 'gini']
# opt/RF\['pad', 'BACK', 15] ['truncate', 'BACK', 15] ['transpose'] ['pca', 6] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9444444444444444
# Best Params: [157, 'entropy']
# opt/RF\['pad', 'BACK', 20] ['truncate', 'BACK', 20] ['pca', 3] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.8703703703703702
# Best Params: [114, 'gini']
# opt/RF\['pad', 'BACK', 20] ['truncate', 'BACK', 20] ['pca', 6] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9259259259259258
# Best Params: [198, 'gini']
# opt/RF\['pad', 'BACK', 20] ['truncate', 'BACK', 20] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.962962962962963
# Best Params: [164, 'entropy']
# opt/RF\['pad', 'BACK', 20] ['truncate', 'BACK', 20] ['transpose'] ['pca', 12] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9444444444444444
# Best Params: [119, 'gini']
# opt/RF\['pad', 'BACK', 20] ['truncate', 'BACK', 20] ['transpose'] ['pca', 6] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9481481481481483
# Best Params: [75, 'entropy']
# opt/RF\['pad', 'BACK', 25] ['truncate', 'BACK', 25] ['pca', 3] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.8333333333333333
# Best Params: [42, 'gini']
# opt/RF\['pad', 'BACK', 25] ['truncate', 'BACK', 25] ['pca', 6] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9185185185185185
# Best Params: [45, 'entropy']
# opt/RF\['pad', 'BACK', 25] ['truncate', 'BACK', 25] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9592592592592594
# Best Params: [129, 'entropy']
# opt/RF\['pad', 'BACK', 25] ['truncate', 'BACK', 25] ['transpose'] ['pca', 12] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9296296296296296
# Best Params: [150, 'entropy']
# opt/RF\['pad', 'BACK', 25] ['truncate', 'BACK', 25] ['transpose'] ['pca', 6] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9481481481481481
# Best Params: [171, 'gini']
# opt/RF\['pad', 'FRONT', 15] ['truncate', 'FRONT', 15] ['pca', 3] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.8148148148148147
# Best Params: [65, 'entropy']
# opt/RF\['pad', 'FRONT', 15] ['truncate', 'FRONT', 15] ['pca', 6] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9370370370370372
# Best Params: [143, 'entropy']
# opt/RF\['pad', 'FRONT', 15] ['truncate', 'FRONT', 15] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9592592592592594
# Best Params: [162, 'entropy']
# opt/RF\['pad', 'FRONT', 15] ['truncate', 'FRONT', 15] ['transpose'] ['pca', 12] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9296296296296298
# Best Params: [143, 'entropy']
# opt/RF\['pad', 'FRONT', 15] ['truncate', 'FRONT', 15] ['transpose'] ['pca', 6] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9481481481481481
# Best Params: [173, 'entropy']
# opt/RF\['pad', 'FRONT', 20] ['truncate', 'FRONT', 20] ['pca', 3] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.837037037037037
# Best Params: [165, 'gini']
# opt/RF\['pad', 'FRONT', 20] ['truncate', 'FRONT', 20] ['pca', 6] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9407407407407409
# Best Params: [144, 'gini']
# opt/RF\['pad', 'FRONT', 20] ['truncate', 'FRONT', 20] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9703703703703704
# Best Params: [200, 'entropy']
# opt/RF\['pad', 'FRONT', 20] ['truncate', 'FRONT', 20] ['transpose'] ['pca', 12] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.937037037037037
# Best Params: [182, 'entropy']
# opt/RF\['pad', 'FRONT', 20] ['truncate', 'FRONT', 20] ['transpose'] ['pca', 6] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.937037037037037
# Best Params: [198, 'gini']
# opt/RF\['pad', 'FRONT', 25] ['truncate', 'FRONT', 25] ['pca', 3] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.8481481481481481
# Best Params: [88, 'gini']
# opt/RF\['pad', 'FRONT', 25] ['truncate', 'FRONT', 25] ['pca', 6] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9407407407407407
# Best Params: [147, 'entropy']
# opt/RF\['pad', 'FRONT', 25] ['truncate', 'FRONT', 25] ['transpose'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.962962962962963
# Best Params: [117, 'entropy']
# opt/RF\['pad', 'FRONT', 25] ['truncate', 'FRONT', 25] ['transpose'] ['pca', 12] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9148148148148149
# Best Params: [145, 'gini']
# opt/RF\['pad', 'FRONT', 25] ['truncate', 'FRONT', 25] ['transpose'] ['pca', 6] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9333333333333333
# Best Params: [90, 'gini']
# opt/RF\['transpose'] ['auto_reg_coeff'] ['flatten'] ['onehot-to-labels'].pkl
# Best Validation Accuracy: 0.9444444444444444
# Best Params: [141, 'gini']

# %%
#get hyper params
